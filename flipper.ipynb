# %%
import numpy as np
import seaborn as sns
import galois

# %%
from flipper import *

# %%
ops = generate_ops()
_ = show_board(ops, highlight_cell=np.arange(9))

# %%
init_state = np.array(
    [[ 1,  1,  1],
     [ 1, -1, -1],
     [ 1, -1, -1]]
)
_ = show_board( init_state)

# %%
solution = solve(init_state)
_ = show_board( solution.reshape((3,3)))

# %%
_ = demo_solution( init_state, solution)

# %% [markdown]
# **Alternative Solution Methods**
#
# The flipper puzzle can also be solved by combining elemental solutions.  An elemental solution is a solution that flips exactly one cell after a sequence of touches.  The solution to the puzzle is the sum of the elemental solutions that flip the cells that are in the down position, modulo 2.

# %%
elemental_states = [
    np.array( [[-1,  1,  1],
               [ 1,  1,  1],
               [ 1,  1,  1]]),
    np.array( [[ 1, -1,  1],
               [ 1,  1,  1],
               [ 1,  1,  1]]),
    np.array( [[ 1,  1,  1],
               [ 1, -1,  1],
               [ 1,  1,  1]])
]

# %%
_ = solve_and_demo( elemental_states[0])

# %%
_ = solve_and_demo( elemental_states[1])

# %%
_ = solve_and_demo( elemental_states[2])

# %%
solution = solve_from_elemental( init_state)
_ = demo_solution( init_state, solution)

# %% [markdown]
# **Some challenging initial configurations**

# %%
init_state = np.array([
    [-1,  1,  1],
    [ 1, -1, -1],
    [ 1, -1, -1]
])
_ = show_board(init_state)
solution = solve( init_state)
_ = show_board( solution.reshape((3,3)))
_ = demo_solution( init_state, solution)

# %%
init_state = np.array([
    [ 1, -1, -1],
    [ 1, -1, -1],
    [ 1, -1, -1]
])
_ = show_board(init_state)
solution = solve( init_state)
_ = show_board( solution.reshape((3,3)))
_ = demo_solution( init_state, solution)

# %%
init_state = np.array([
    [ 1, -1, -1],
    [ 1, -1,  1],
    [ 1, -1, -1]
])
_ = show_board(init_state)
solution = solve( init_state)
_ = show_board( solution.reshape((3,3)))
_ = demo_solution( init_state, solution)

# %%
init_state = np.array([
    [ 1, -1,  1],
    [-1,  1,  1],
    [ 1,  1,  1]
])
_ = show_board(init_state)
solution = solve( init_state)
_ = show_board( solution.reshape((3,3)))
_ = demo_solution( init_state, solution)

# %%
init_state = np.array([
    [-1,  1,  1],
    [ 1, -1,  1],
    [ 1,  1,  1]
])
_ = show_board(init_state)
solution = solve( init_state)
_ = show_board( solution.reshape((3,3)))
_ = demo_solution( init_state, solution)

# %%
init_state = np.array([
    [ 1, -1,  1],
    [ 1, -1,  1],
    [ 1,  1,  1]
])
_ = show_board(init_state)
solution = solve( init_state)
_ = show_board( solution.reshape((3,3)))
_ = demo_solution( init_state, solution)

# %%
init_state = np.array([
    [ 1, -1,  1],
    [ 1, -1,  1],
    [ 1, -1,  1]
])
_ = show_board(init_state)
solution = solve( init_state)
_ = show_board( solution.reshape((3,3)))
_ = demo_solution( init_state, solution)

# %%
init_state = np.array([
    [-1, -1,  1],
    [ 1,  1, -1],
    [ 1,  1,  1]
])
_ = show_board(init_state)
solution = solve( init_state)
_ = show_board( solution.reshape((3,3)))
_ = demo_solution( init_state, solution)
